# %%
from sklearn.datasets import load_iris, fetch_california_housing
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("../Data/Raw/health_lifestyle_classification.csv")
df
# Out:
#        survey_code  age  gender      height     weight        bmi  \
# 0                1   56    Male  173.416872  56.886640  18.915925
# 1                2   69  Female  163.207380  97.799859  36.716278
# 2                3   46    Male  177.281966  80.687562  25.673050
# 3                4   32  Female  172.101255  63.142868  21.318480
# 4                5   60  Female  163.608816  40.000000  14.943302
# ...            ...  ...     ...         ...        ...        ...
# 99995        99996   53    Male  177.202253  54.303671  17.293811
# 99996        99997   22    Male  180.802297  40.033853  12.246712
# 99997        99998   37    Male  185.540653  84.536847  24.556580
# 99998        99999   72  Female  181.796786  56.923335  17.223362
# 99999       100000   37    Male  175.716378  93.017286  30.125841
#
#        bmi_estimated  bmi_scaled  bmi_corrected  waist_size  ...  \
# 0          18.915925   56.747776      18.989117   72.165130  ...
# ...

# %%
df.shape
# Out:
# (100000, 48)

# %%
df.isnull().sum()
# Out:
# survey_code                     0
# age                             0
# gender                          0
# height                          0
# weight                          0
# bmi                             0
# bmi_estimated                   0
# bmi_scaled                      0
# bmi_corrected                   0
# waist_size                      0
# blood_pressure               7669
# heart_rate                  14003
# cholesterol                     0
# glucose                         0
# insulin                     15836
# sleep_hours                     0
# sleep_quality                   0
# work_hours                      0
# physical_activity               0
# daily_steps                  8329
# calorie_intake                  0
# sugar_intake                    0
# alcohol_consumption         42387
# smoking_level                   0
# water_intake                    0
# screen_time                     0
# stress_level                    0
# ...

# %%
df["physical_activity"].unique
# Out:
# <bound method Series.unique of 0        0.356918
# 1        0.568219
# 2        3.764406
# 3        0.889474
# 4        2.901608
#            ...
# 99995    2.016794
# 99996    1.988679
# 99997    2.018741
# 99998    5.419878
# 99999    4.980099
# Name: physical_activity, Length: 100000, dtype: float64>

# %%
df_2 = df.drop(['bmi_estimated', 'bmi_scaled', 'bmi_corrected', 'insurance', 'income', 'gene_marker_flag', 'education_level', 'occupation', 'electrolyte_level'], axis=1)
df_2
# Out:
#        survey_code  age  gender      height     weight        bmi  waist_size  \
# 0                1   56    Male  173.416872  56.886640  18.915925   72.165130
# 1                2   69  Female  163.207380  97.799859  36.716278   85.598889
# 2                3   46    Male  177.281966  80.687562  25.673050   90.295030
# 3                4   32  Female  172.101255  63.142868  21.318480  100.504211
# 4                5   60  Female  163.608816  40.000000  14.943302   69.021150
# ...            ...  ...     ...         ...        ...        ...         ...
# 99995        99996   53    Male  177.202253  54.303671  17.293811   88.740028
# 99996        99997   22    Male  180.802297  40.033853  12.246712  103.659560
# 99997        99998   37    Male  185.540653  84.536847  24.556580   98.920422
# 99998        99999   72  Female  181.796786  56.923335  17.223362   54.559079
# 99999       100000   37    Male  175.716378  93.017286  30.125841   70.743851
#
# ...

# %%
df_2 = df_2.dropna()
df_2
# Out:
#        survey_code  age  gender      height     weight        bmi  waist_size  \
# 1                2   69  Female  163.207380  97.799859  36.716278   85.598889
# 10              11   36    Male  154.018148  72.899782  30.731407   71.862592
# 17              18   57  Female  163.716032  80.649500  30.089797   98.126084
# 18              19   41  Female  176.073128  66.658527  21.501539   76.524816
# 27              28   19    Male  159.247214  49.841623  19.653889   75.533214
# ...            ...  ...     ...         ...        ...        ...         ...
# 99986        99987   62    Male  168.934896  78.042746  27.346000   76.433630
# 99987        99988   37  Female  162.510812  64.955967  24.595436   76.825530
# 99989        99990   24  Female  178.190353  79.022329  24.887510  103.810718
# 99994        99995   41    Male  155.398936  57.362689  23.753818   77.105189
# 99998        99999   72  Female  181.796786  56.923335  17.223362   54.559079
#
# ...

# %%
df_2['smoking_level'].unique()
# Out:
# array(['Light', 'Non-smoker', 'Heavy'], dtype=object)

# %%
smoking_map = {
    'Non-smoker': 1,
    'Light': 2,
    'Heavy': 3
}

df_2.loc[:, 'smoking_level'] = df_2['smoking_level'].map(smoking_map)
smoking_map
# Out:
# {'Non-smoker': 1, 'Light': 2, 'Heavy': 3}

# %%
smoking_map = {
    'Non-smoker': 1,
    'Light': 2,
    'Heavy': 3
}

df_2.loc[:, 'smoking_level'] = df_2['smoking_level'].map(smoking_map)
smoking_map

# %%
df_2['mental_health_support'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
mental_health_map = {
    'No': 1,
    'Yes': 2,
}

df_2.loc[:, 'mental_health_support'] = df_2['mental_health_support'].map(mental_health_map)
mental_health_map
# Out:
# {'No': 1, 'Yes': 2}

# %%
df_2['job_type'].unique()
# Out:
# array(['Office', 'Labor', 'Service', 'Unemployed', 'Healthcare', 'Tech'],
#       dtype=object)

# %%
job_type_map = {
    'Office': 1,
    'Labor': 2,
    'Service': 3,
    'Unemployed': 4,
    'Healthcare': 5,
    'Tech': 6
}

df_2.loc[:, 'job_type'] = df_2['job_type'].map(job_type_map)
job_type_map
# Out:
# {'Office': 1,
#  'Labor': 2,
#  'Service': 3,
#  'Unemployed': 4,
#  'Healthcare': 5,
#  'Tech': 6}

# %%
df_2['diet_type'].unique()
# Out:
# array(['Vegan', 'Omnivore', 'Keto', 'Vegetarian'], dtype=object)

# %%
diet_type_map = {
    'Vegan': 1,
    'Omnivore': 2,
    'Keto': 3,
    'Vegetarian': 4
}

df_2.loc[:, 'diet_type'] = df_2['diet_type'].map(diet_type_map)
diet_type_map
# Out:
# {'Vegan': 1, 'Omnivore': 2, 'Keto': 3, 'Vegetarian': 4}
